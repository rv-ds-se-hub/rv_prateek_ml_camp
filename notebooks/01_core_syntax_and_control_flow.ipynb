# %% [markdown]
# # 1. Warm Up
#
# - Working Jupyter Lab
#
# - Any confusing Python topics?

# %% [markdown]
# # 2. Mini-Recap
#
# - Class 0
# - We want to start with basics before hitting the "pro-habits"
# - Goal for this lesson is to build a strong foundation by mastering: Variables & Types, Collections, Control Flow & Good Coding Habits.

# %% [markdown]
# # 3. Concept Drop

# %% [markdown]
# ## Variables are Labels

# %% [markdown]
# ## Collections store multiple items

# %% [markdown]
# ## Control Flow Makes decision

# %% [markdown]
# # 4. Guided Practice: Planning A Weekend Trip

# %% [markdown]
# ## Part 1: Defining Our Trip:
# ### Let's start by defining the basic details of our trip using variables. We need a destination, a duration in days, and whether the booking is confirmed.

# %% [markdown]
# ## Part 2: Listing Activities and Their Costs
#
# ### A simple list is good for activities, but what about their costs? A list of dictionaries is perfect for this! Each dictionary can hold information about a single activity.

# %% [markdown]
# ## Part 3: The Budget Decider (Putting it all together)
#
# ### Now for the most important part. We have a budget. Let's write a program that iterates through our planned activities and tells us which ones we can actually afford. This combines for loops and if statements.

# %% [markdown]
# # 5. Wrap up

# %% [markdown]
# ### Write your own mini trip planner:
#
# 1. Pick your favorite city or event.
#
# 2.  Define at least 3 activities (with costs & one more property, e.g., time required, rating, or a boolean like “is_outdoor”).
#
# 3. User input: ask for a budget.
#
# 4. Print all activities user can afford (iterate and filter).
#
# 5. Add at least one additional logic—e.g., exclude all “outdoor” activities if user says it’s raining.

# %% [markdown]
# # 6. Notes (during class)

# %% [markdown]
# - xyz

# %% [markdown]
# ---

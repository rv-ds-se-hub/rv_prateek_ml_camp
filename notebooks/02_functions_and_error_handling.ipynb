# %% [markdown]
# # 1. Warm Up

# %% [markdown]
# # 2. Mini-Recap
#
# Last time, we wrote a script to do one thing. Today, we'll learn how to package that logic so we can reuse it easily and make it fail-proof.

# %% [markdown]
# # 3. Concept Drop

# %% [markdown]
# ## Functions: What & Why?

# %% [markdown]
# ## Docstrings

# %% [markdown]
# ## Errors

# %% [markdown]
# # 4. Guided Practice: Refactor Planning A Weekend Trip

# %% [markdown]
# ### Let's take the "Budget Decider" logic from our last class and turn it into a function. This will allow us to run it for any budget and any list of activities without rewriting code. Our function will take a budget and activity_list as inputs and should return a new list of affordable activities.

# %% [markdown]
# ### Our function works, but six months from now, we'll forget exactly how. A docstring is a special comment that explains what a function does. Let's add one.

# %% [markdown]
# ### What happens if someone gives our function bad data? For example, a string for the budget? Let's see it break, and then fix it with try...except.

# %% [markdown]
# # 5. Wrap up

# %% [markdown]
# ### Recap: DDD - Define, Document, Debug workflow.
#
# ### HW:
# Write a function calculate_average(numbers) that takes a list of numbers and returns their average. It must handle two error cases:
#  1) if the list is empty (which would cause a ZeroDivisionError), and
#  2) if the list contains non-numeric values (a TypeError).

# %% [markdown]
# # 6. Notes (during class)

# %% [markdown]
# - xyz

# %% [markdown]
# ---

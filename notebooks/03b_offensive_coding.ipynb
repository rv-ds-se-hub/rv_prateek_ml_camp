# %% [markdown]
# ### This is a continuation of defensive programming techniques. Sometimes the best defense is offense.

# %%
def calculate_trade_value(price, quantity):
    if price <= 0:
        return 0
    return price * quantity

# %%
portfolio = [
    {"id": 1, "price": 100, "quantity": 5},
    {"id": 2, "price": -50, "quantity": 10},  # Bad data
]

total_val = 0
for trade in portfolio:
    total_val += calculate_trade_value(
        trade["price"],
        trade["quantity"]
    )

print("Total Portfolio Value:", total_val)
# Out:
# Total Portfolio Value: 500

# %% [markdown]
# - Trade 2 is invalid
# - Portfolio value is wrong
# - System continues happily
#
# Worst outcome in finance.

# %% [markdown]
# #### Returning fake value is worse than crashing it.

# %%
def calculate_trade_value_offensive(price, quantity):
    if price <= 0:
        raise ValueError(f"Invalid price: {price}")
    return price * quantity

total_val = 0
for trade in portfolio:
    total_val += calculate_trade_value_offensive(
        trade["price"],
        trade["quantity"]
    )

print("Total Portfolio Value:", total_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       6 total_val = 0
#       7 for trade in portfolio:
# ----> 8     total_val += calculate_trade_value_offensive(
#       9         trade["price"],
#      10         trade["quantity"]
#      11     )
#      13 print("Total Portfolio Value:", total_val)
#
# Cell In[6], line 3, in calculate_trade_value_offensive(price, quantity)
#       1 def calculate_trade_value_offensive(price, quantity):
#       2     if price <= 0:
# ----> 3         raise ValueError(f"Invalid price: {price}")
#       4     return price * quantity
#
# ValueError: Invalid price: -50

# %% [markdown]
# Before raising errors, let's understand what errors exist:
#
# Python has a rich hierarchy of exceptions.
#
# Everything ultimately derives from  ```BaseException``` class in Python.
# Most application errors derive from ```Exception```

# %% [markdown]
# #### ValueError
#
# - Raised when we have correct type but wrong value
# - int("abc")
#
# #### TypeError
#
# - Raised when we have the wrong type
# - 1 + "hi"
#
# #### KeyError
#
# - Raised when dictionary key is missing
#
#
# #### IndexError
#
# - Raised when list index is out of range
#
# #### ZeroDivisionError
#
# - Raised when we divide by zero.
#
#
# #### AssertionError
#
# - Raised when an ```assert``` statement fails.

# %% [markdown]
# Choosing the correct exception type is important:
#
# - Improves readability
# - Improves debugging
# - Improves logging

# %% [markdown]
# ### Example 1 : validating inputs

# %%
def withdraw(balance, amount):
    if amount < 0:
        raise ValueError("Amount cannot be negative.")
    if amount > balance:
        raise ValueError("Insufficient funds.")

    return balance - amount

# %%
withdraw(2000, 4000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 withdraw(2000, 4000)
#
# Cell In[14], line 5, in withdraw(balance, amount)
#       3     raise ValueError("Amount cannot be negative.")
#       4 if amount > balance:
# ----> 5     raise ValueError("Insufficient funds.")
#       7 return balance - amount
#
# ValueError: Insufficient funds.

# %%
withdraw(1000, 900)
# Out:
# 100

# %% [markdown]
# ### Example 2 - Type checking

# %%
def process_trade(price):
    if not isinstance(price, (int, float)):
        raise TypeError("Price must be numeric.")

    return price

# %%
process_trade(10)
# Out:
# 10

# %%
process_trade("hi")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 process_trade("hi")
#
# Cell In[19], line 3, in process_trade(price)
#       1 def process_trade(price):
#       2     if not isinstance(price, (int, float)):
# ----> 3         raise TypeError("Price must be numeric.")
#       5     return price
#
# TypeError: Price must be numeric.

# %% [markdown]
# ## Important: Never raise generic exceptions. ```raise Exception("something is wrong")```
#
# - Too vague and not specific.
